# %%
# !pip install sentence-transformers
# !pip install fastai
# !pip install git+https://github.com/openai/CLIP.git
# !pip install newlinejson
# Out:
# Requirement already satisfied: sentence-transformers in /opt/conda/lib/python3.9/site-packages (2.0.0)
# Requirement already satisfied: sentencepiece in /opt/conda/lib/python3.9/site-packages (from sentence-transformers) (0.1.96)
# Requirement already satisfied: huggingface-hub in /opt/conda/lib/python3.9/site-packages (from sentence-transformers) (0.0.16)
# Requirement already satisfied: torchvision in /opt/conda/lib/python3.9/site-packages (from sentence-transformers) (0.10.0)
# Requirement already satisfied: transformers<5.0.0,>=4.6.0 in /opt/conda/lib/python3.9/site-packages (from sentence-transformers) (4.10.0)
# Requirement already satisfied: nltk in /opt/conda/lib/python3.9/site-packages (from sentence-transformers) (3.6.2)
# Requirement already satisfied: tqdm in /opt/conda/lib/python3.9/site-packages (from sentence-transformers) (4.61.2)
# Requirement already satisfied: numpy in /opt/conda/lib/python3.9/site-packages (from sentence-transformers) (1.21.1)
# Requirement already satisfied: scikit-learn in /opt/conda/lib/python3.9/site-packages (from sentence-transformers) (0.24.2)
# Requirement already satisfied: torch>=1.6.0 in /opt/conda/lib/python3.9/site-packages (from sentence-transformers) (1.9.0)
# Requirement already satisfied: scipy in /opt/conda/lib/python3.9/site-packages (from sentence-transformers) (1.7.0)
# Requirement already satisfied: typing-extensions in /opt/conda/lib/python3.9/site-packages (from torch>=1.6.0->sentence-transformers) (3.10.0.0)
# Requirement already satisfied: filelock in /opt/conda/lib/python3.9/site-packages (from transformers<5.0.0,>=4.6.0->sentence-transformers) (3.0.12)
# Requirement already satisfied: sacremoses in /opt/conda/lib/python3.9/site-packages (from transformers<5.0.0,>=4.6.0->sentence-transformers) (0.0.45)
# Requirement already satisfied: tokenizers<0.11,>=0.10.1 in /opt/conda/lib/python3.9/site-packages (from transformers<5.0.0,>=4.6.0->sentence-transformers) (0.10.3)
# Requirement already satisfied: requests in /opt/conda/lib/python3.9/site-packages (from transformers<5.0.0,>=4.6.0->sentence-transformers) (2.26.0)
# Requirement already satisfied: packaging in /opt/conda/lib/python3.9/site-packages (from transformers<5.0.0,>=4.6.0->sentence-transformers) (21.0)
# Requirement already satisfied: regex!=2019.12.17 in /opt/conda/lib/python3.9/site-packages (from transformers<5.0.0,>=4.6.0->sentence-transformers) (2021.7.6)
# Requirement already satisfied: pyyaml>=5.1 in /opt/conda/lib/python3.9/site-packages (from transformers<5.0.0,>=4.6.0->sentence-transformers) (5.4.1)
# Requirement already satisfied: pyparsing>=2.0.2 in /opt/conda/lib/python3.9/site-packages (from packaging->transformers<5.0.0,>=4.6.0->sentence-transformers) (2.4.7)
# Requirement already satisfied: joblib in /opt/conda/lib/python3.9/site-packages (from nltk->sentence-transformers) (1.0.1)
# Requirement already satisfied: click in /opt/conda/lib/python3.9/site-packages (from nltk->sentence-transformers) (7.1.2)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /opt/conda/lib/python3.9/site-packages (from requests->transformers<5.0.0,>=4.6.0->sentence-transformers) (2.0.0)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/conda/lib/python3.9/site-packages (from requests->transformers<5.0.0,>=4.6.0->sentence-transformers) (2021.5.30)
# Requirement already satisfied: idna<4,>=2.5 in /opt/conda/lib/python3.9/site-packages (from requests->transformers<5.0.0,>=4.6.0->sentence-transformers) (3.1)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /opt/conda/lib/python3.9/site-packages (from requests->transformers<5.0.0,>=4.6.0->sentence-transformers) (1.26.6)
# Requirement already satisfied: six in /opt/conda/lib/python3.9/site-packages (from sacremoses->transformers<5.0.0,>=4.6.0->sentence-transformers) (1.16.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /opt/conda/lib/python3.9/site-packages (from scikit-learn->sentence-transformers) (2.2.0)
# Requirement already satisfied: pillow>=5.3.0 in /opt/conda/lib/python3.9/site-packages (from torchvision->sentence-transformers) (8.3.1)
# Requirement already satisfied: fastai in /opt/conda/lib/python3.9/site-packages (2.5.2)
# Requirement already satisfied: pip in /opt/conda/lib/python3.9/site-packages (from fastai) (21.2.1)
# Requirement already satisfied: matplotlib in /opt/conda/lib/python3.9/site-packages (from fastai) (3.4.2)
# Requirement already satisfied: pillow>6.0.0 in /opt/conda/lib/python3.9/site-packages (from fastai) (8.3.1)
# Requirement already satisfied: scikit-learn in /opt/conda/lib/python3.9/site-packages (from fastai) (0.24.2)
# Requirement already satisfied: fastcore<1.4,>=1.3.8 in /opt/conda/lib/python3.9/site-packages (from fastai) (1.3.26)
# Requirement already satisfied: fastdownload<2,>=0.0.5 in /opt/conda/lib/python3.9/site-packages (from fastai) (0.0.5)
# Requirement already satisfied: spacy<4 in /opt/conda/lib/python3.9/site-packages (from fastai) (3.1.2)
# Requirement already satisfied: requests in /opt/conda/lib/python3.9/site-packages (from fastai) (2.26.0)
# Requirement already satisfied: torch<1.10,>=1.7.0 in /opt/conda/lib/python3.9/site-packages (from fastai) (1.9.0)
# Requirement already satisfied: fastprogress>=0.2.4 in /opt/conda/lib/python3.9/site-packages (from fastai) (1.0.0)
# Requirement already satisfied: pyyaml in /opt/conda/lib/python3.9/site-packages (from fastai) (5.4.1)
# Requirement already satisfied: scipy in /opt/conda/lib/python3.9/site-packages (from fastai) (1.7.0)
# Requirement already satisfied: pandas in /opt/conda/lib/python3.9/site-packages (from fastai) (1.3.1)
# Requirement already satisfied: torchvision>=0.8.2 in /opt/conda/lib/python3.9/site-packages (from fastai) (0.10.0)
# Requirement already satisfied: packaging in /opt/conda/lib/python3.9/site-packages (from fastai) (21.0)
# Requirement already satisfied: numpy in /opt/conda/lib/python3.9/site-packages (from fastprogress>=0.2.4->fastai) (1.21.1)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.4 in /opt/conda/lib/python3.9/site-packages (from spacy<4->fastai) (2.0.6)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in /opt/conda/lib/python3.9/site-packages (from spacy<4->fastai) (2.0.5)
# Requirement already satisfied: blis<0.8.0,>=0.4.0 in /opt/conda/lib/python3.9/site-packages (from spacy<4->fastai) (0.7.4)
# Requirement already satisfied: typer<0.4.0,>=0.3.0 in /opt/conda/lib/python3.9/site-packages (from spacy<4->fastai) (0.3.2)
# Requirement already satisfied: srsly<3.0.0,>=2.4.1 in /opt/conda/lib/python3.9/site-packages (from spacy<4->fastai) (2.4.1)
# Requirement already satisfied: setuptools in /opt/conda/lib/python3.9/site-packages (from spacy<4->fastai) (49.6.0.post20210108)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.7 in /opt/conda/lib/python3.9/site-packages (from spacy<4->fastai) (3.0.8)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in /opt/conda/lib/python3.9/site-packages (from spacy<4->fastai) (1.0.5)
# Requirement already satisfied: jinja2 in /opt/conda/lib/python3.9/site-packages (from spacy<4->fastai) (3.0.1)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,<1.9.0,>=1.7.4 in /opt/conda/lib/python3.9/site-packages (from spacy<4->fastai) (1.8.2)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in /opt/conda/lib/python3.9/site-packages (from spacy<4->fastai) (4.61.2)
# Requirement already satisfied: pathy>=0.3.5 in /opt/conda/lib/python3.9/site-packages (from spacy<4->fastai) (0.6.0)
# Requirement already satisfied: thinc<8.1.0,>=8.0.8 in /opt/conda/lib/python3.9/site-packages (from spacy<4->fastai) (8.0.9)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in /opt/conda/lib/python3.9/site-packages (from spacy<4->fastai) (3.0.5)
# Requirement already satisfied: wasabi<1.1.0,>=0.8.1 in /opt/conda/lib/python3.9/site-packages (from spacy<4->fastai) (0.8.2)
# Requirement already satisfied: pyparsing>=2.0.2 in /opt/conda/lib/python3.9/site-packages (from packaging->fastai) (2.4.7)
# Requirement already satisfied: smart-open<6.0.0,>=5.0.0 in /opt/conda/lib/python3.9/site-packages (from pathy>=0.3.5->spacy<4->fastai) (5.2.1)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /opt/conda/lib/python3.9/site-packages (from pydantic!=1.8,!=1.8.1,<1.9.0,>=1.7.4->spacy<4->fastai) (3.10.0.0)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /opt/conda/lib/python3.9/site-packages (from requests->fastai) (2.0.0)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /opt/conda/lib/python3.9/site-packages (from requests->fastai) (1.26.6)
# Requirement already satisfied: idna<4,>=2.5 in /opt/conda/lib/python3.9/site-packages (from requests->fastai) (3.1)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/conda/lib/python3.9/site-packages (from requests->fastai) (2021.5.30)
# Requirement already satisfied: click<7.2.0,>=7.1.1 in /opt/conda/lib/python3.9/site-packages (from typer<0.4.0,>=0.3.0->spacy<4->fastai) (7.1.2)
# Requirement already satisfied: MarkupSafe>=2.0 in /opt/conda/lib/python3.9/site-packages (from jinja2->spacy<4->fastai) (2.0.1)
# Requirement already satisfied: cycler>=0.10 in /opt/conda/lib/python3.9/site-packages (from matplotlib->fastai) (0.10.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /opt/conda/lib/python3.9/site-packages (from matplotlib->fastai) (1.3.1)
# Requirement already satisfied: python-dateutil>=2.7 in /opt/conda/lib/python3.9/site-packages (from matplotlib->fastai) (2.8.2)
# Requirement already satisfied: six in /opt/conda/lib/python3.9/site-packages (from cycler>=0.10->matplotlib->fastai) (1.16.0)
# Requirement already satisfied: pytz>=2017.3 in /opt/conda/lib/python3.9/site-packages (from pandas->fastai) (2021.1)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /opt/conda/lib/python3.9/site-packages (from scikit-learn->fastai) (2.2.0)
# Requirement already satisfied: joblib>=0.11 in /opt/conda/lib/python3.9/site-packages (from scikit-learn->fastai) (1.0.1)
# Collecting git+https://github.com/openai/CLIP.git
#   Cloning https://github.com/openai/CLIP.git to /tmp/pip-req-build-c94ifqwg
#   Running command git clone -q https://github.com/openai/CLIP.git /tmp/pip-req-build-c94ifqwg
#   Resolved https://github.com/openai/CLIP.git to commit 3b473b0e682c091a9e53623eebc1ca1657385717
# Requirement already satisfied: ftfy in /opt/conda/lib/python3.9/site-packages (from clip==1.0) (6.0.3)
# Requirement already satisfied: regex in /opt/conda/lib/python3.9/site-packages (from clip==1.0) (2021.7.6)
# Requirement already satisfied: tqdm in /opt/conda/lib/python3.9/site-packages (from clip==1.0) (4.61.2)
# Requirement already satisfied: torch in /opt/conda/lib/python3.9/site-packages (from clip==1.0) (1.9.0)
# Requirement already satisfied: torchvision in /opt/conda/lib/python3.9/site-packages (from clip==1.0) (0.10.0)
# Requirement already satisfied: wcwidth in /opt/conda/lib/python3.9/site-packages (from ftfy->clip==1.0) (0.2.5)
# Requirement already satisfied: typing-extensions in /opt/conda/lib/python3.9/site-packages (from torch->clip==1.0) (3.10.0.0)
# Requirement already satisfied: numpy in /opt/conda/lib/python3.9/site-packages (from torchvision->clip==1.0) (1.21.1)
# Requirement already satisfied: pillow>=5.3.0 in /opt/conda/lib/python3.9/site-packages (from torchvision->clip==1.0) (8.3.1)
# Requirement already satisfied: newlinejson in /opt/conda/lib/python3.9/site-packages (1.0)
# Requirement already satisfied: six in /opt/conda/lib/python3.9/site-packages (from newlinejson) (1.16.0)
