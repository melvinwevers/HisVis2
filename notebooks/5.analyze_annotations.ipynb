# %% [markdown]
# # Analyze Annotations
#
# In this notebook, we examine the annotation data.

# %%
import json
import matplotlib.pyplot as plt 
import numpy as np

import os
import pandas as pd
import seaborn as sns

from sklearn.metrics import accuracy_score
from sklearn.metrics import confusion_matrix

# %%
output_path = ('../data/processed/')

# %%
# this only looks at step 1 and 2

df1 = pd.read_csv(os.path.join(output_path, 'annotation_data_step_1.csv')).drop('Unnamed: 0', axis=1)
df2 = pd.read_csv(os.path.join(output_path, 'annotation_data_step_2.csv'))

df2 = df2[(df2['corrected_label'] != 'buiten') & (df2['corrected_label'] != 'binnen') & (df2['corrected_label'] != 'no_description_found')]

df_all = pd.concat([df1, df2])

# %% [markdown]
# ## Categories with fewer than 50 images

# %%
extra_training = list(df_all['corrected_label'].value_counts().loc[lambda x : x <50].index)

# %% [markdown]
# ## Top 5 Accuracy

# %%
#remove binnen / buiten annotations



step1_top1_acc = df1.groupby('corrected_label')['in_top_1'].mean()
step2_top1_acc = df2.groupby('corrected_label')['in_top_1'].mean()


step1_top5_acc = df1.groupby('corrected_label')['in_top_5'].mean()
step2_top5_acc = df2.groupby('corrected_label')['in_top_5'].mean()

top_1_acc = pd.merge(pd.Series(step1_top1_acc, name='step1'), pd.Series(step2_top1_acc, name='step2'), right_index = True,
               left_index = True, how='right').round(3)


top_5_acc = pd.merge(pd.Series(step1_top5_acc, name='step1'), pd.Series(step2_top5_acc, name='step2'), right_index = True,
               left_index = True, how='right').round(3)

comparison = []
for row in top_5_acc.iterrows():
    if row[1]['step1'] - row[1]['step2'] < -0.05 :
        comparison.append('increase')
    elif row[1]['step1'] - row[1]['step2'] > 0.05 :
        comparison.append('decrease')
    else:
        comparison.append('no change')

top_5_acc['state'] = comparison
top_5_acc['diff'] = top_5_acc['step1'] - top_5_acc['step2']

top_5_acc.sort_values('diff', ascending=True).head(50)
top_5_acc.to_csv('top_5_acc.csv')

# %% [markdown]
# ## 25 Lowest accuracy

# %%
top_5_acc.sort_values('step2').head(25)
# Out:
#                   step1  step2      state   diff
# corrected_label
# boksen            0.889  0.000   decrease  0.889
# casino              NaN  0.000  no change    NaN
# stemlokaal          NaN  0.000  no change    NaN
# tennis            0.889  0.000   decrease  0.889
# biljart             NaN  0.000  no change    NaN
# spoorweg            NaN  0.000  no change    NaN
# kermis            0.286  0.000   decrease  0.286
# rugby             0.857  0.000   decrease  0.857
# helikopter          NaN  0.000  no change    NaN
# vuilnisbelt         NaN  0.000  no change    NaN
# waterpolo         1.000  0.000   decrease  1.000
# windsurfen        0.889  0.000   decrease  0.889
# carnaval            NaN  0.000  no change    NaN
# kaartspel         0.750  0.000   decrease  0.750
# bordspel            NaN  0.000  no change    NaN
# tram              0.500  0.250   decrease  0.250
# sport_overig        NaN  0.255  no change    NaN
# zwaan             0.800  0.308   decrease  0.492
# mensen_op_trap    0.333  0.364  no change -0.031
# kerstmis          0.765  0.373   decrease  0.392
# trein_ongeluk     0.500  0.429   decrease  0.071
# vliegtuig           NaN  0.442  no change    NaN
# vlag_hijsen       0.071  0.464   increase -0.393
# ongeluk_brancard  0.571  0.467   decrease  0.104
# golf                NaN  0.476  no change    NaN

# %%
lowest_acc = list(top_5_acc.sort_values('step2').head(25).index)
extra_training = list(set(extra_training + lowest_acc))

# %% [markdown]
# ## Decreased accuracy

# %%
decreased_acc = list(top_5_acc[top_5_acc['state'] == 'decrease'].index)

# %% [markdown]
# ## Error Analysis

# %%
df2[df2['top_1'] == 'zwaan']['corrected_label'].value_counts()
# Out:
# zwaan     6
# eend      6
# vogels    2
# Name: corrected_label, dtype: int64

# %%
df2[df2['corrected_label'] == 'zwaan']['top_1'].value_counts()
# Out:
# dieren_overig    6
# zwaan            6
# standbeeld       2
# roeien           2
# strand           2
# vijver_plas      2
# straat           2
# voetbal          2
# schaatsen        2
# Name: top_1, dtype: int64

# %%
df2[df2['top_1'] == 'trein']['corrected_label'].value_counts()
# Out:
# trein_station           14
# trein                   12
# bouwplaats               4
# trein_ongeluk            2
# boten                    2
# no_description_found     2
# huisje                   2
# Name: corrected_label, dtype: int64

# %%
df2[df2['corrected_label'] == 'trein']['top_1'].value_counts()
# Out:
# trein            12
# bus_truck         6
# ziekenhuis        4
# trein_station     4
# fabriek           4
# trein_ongeluk     2
# keuken            2
# bouwplaats        2
# brug              2
# portret           2
# optocht           2
# demonstratie      2
# gebouw            2
# Name: top_1, dtype: int64

# %%
df2[(df2['top_1'] =='bus_truck') & (df2['corrected_label'] == 'trein')]
# Out:
#                                              predictions      top_1  \
# 3944   {'cafe': 0.03, 'trein': 0.04, 'auto': 0.09, 'v...  bus_truck
# 3945   {'cafe': 0.03, 'trein': 0.04, 'auto': 0.09, 'v...  bus_truck
# 5602   {'trein_station': 0.05, 'straat': 0.06, 'verga...  bus_truck
# 5603   {'trein_station': 0.05, 'straat': 0.06, 'verga...  bus_truck
# 41643  {'straat': 0.04, 'auto': 0.04, 'mensen_op_een_...  bus_truck
# 41644  {'straat': 0.04, 'auto': 0.04, 'mensen_op_een_...  bus_truck
#
#                                                    top_5  \
# 3944   ['cafe', 'trein', 'auto', 'vergaderruimte', 'b...
# 3945   ['cafe', 'trein', 'auto', 'vergaderruimte', 'b...
# 5602   ['trein_station', 'straat', 'vergaderruimte', ...
# 5603   ['trein_station', 'straat', 'vergaderruimte', ...
# 41643  ['straat', 'auto', 'mensen_op_een_boot', 'gebo...
# 41644  ['straat', 'auto', 'mensen_op_een_boot', 'gebo...
#
#                             title  image_id  scan_id  too_difficult  unusable  \
# 3944   NL-HlmNHA_1478_15535B00_01     55748    25756              0         0
# 3945   NL-HlmNHA_1478_15535B00_01     55748    25756              0         0
# 5602   NL-HlmNHA_1478_15659B00_01     59429    29437              0         0
# 5603   NL-HlmNHA_1478_15659B00_01     59429    29437              0         0
# 41643  NL-HlmNHA_1478_33985K01_10     54009    24017              0         1
# 41644  NL-HlmNHA_1478_33985K01_10     54009    24017              0         1
#
#               annotated_on  annotator_id annotated_label           checked_on  \
# 3944   2022-04-19 14:49:36          2676       bus_truck  2022-05-13 19:32:25
# 3945   2022-04-19 15:17:54         23849           trein  2022-05-13 19:32:25
# 5602   2022-04-26 16:05:18         13212           trein  2022-05-19 21:45:48
# 5603   2022-04-26 17:03:21         21038           trein  2022-05-19 21:45:48
# 41643  2022-04-16 11:44:27         21351           trein  2022-05-10 09:53:54
# 41644  2022-04-16 15:50:09         23655           trein  2022-05-10 09:53:54
#
#        validator_id corrected_label              toelichting  gebruiker_id  \
# 3944          17916           trein                      NaN           NaN
# 3945          17916           trein                      NaN           NaN
# 5602          17916           trein                      NaN           NaN
# 5603          17916           trein                      NaN           NaN
# 41643          9686           trein  Treinwagon in onderhoud        9686.0
# 41644          9686           trein  Treinwagon in onderhoud        9686.0
#
#       agreement  in_top_1  in_top_5
# 3944   disagree         0         1
# 3945   disagree         0         1
# 5602      agree         0         0
# 5603      agree         0         0
# 41643     agree         0         0
# 41644     agree         0         0

# %%
df2[df2['top_1'] == 'kerstmis']['corrected_label'].value_counts()
# Out:
# kerstmis    12
# Name: corrected_label, dtype: int64

# %%
df2[df2['corrected_label'] == 'kerstmis']['top_1'].value_counts()
# Out:
# gebouw                    14
# kerstmis                  12
# portret                    8
# straat                     8
# winkel_binnen              8
# muziek_optreden            6
# uitreiking_huldiging       6
# borden_gevelsteen          4
# sinterklaas                4
# toren                      4
# plattegrond                2
# kerk_buiten                2
# theater                    2
# akker                      2
# woonwijk                   2
# bibliotheek_boekwinkel     2
# klaslokaal                 2
# etalage                    2
# bloemen                    2
# speech                     2
# brug                       2
# standbeeld                 2
# etende_mensen              2
# mensenmassa                2
# Name: top_1, dtype: int64

# %%
df2[df2['corrected_label'] == 'kermis']['top_1'].value_counts()
# Out:
# circus                24
# markt                 10
# mensenmassa            6
# zeepkistenrace         4
# mensen_op_een_boot     4
# optocht                4
# gymnastiek             4
# kerk_buiten            2
# auto                   2
# portret                2
# kamperen               2
# fietsende_mensen       2
# etalage                2
# theater                2
# demonstratie           2
# brand                  2
# klaslokaal             2
# Name: top_1, dtype: int64

# %%
df2[df2['top_1'] == 'tram']['corrected_label'].value_counts()
# Out:
# straat           2
# trein_station    2
# winkel_binnen    2
# Name: corrected_label, dtype: int64

# %%
meta_df = pd.read_csv('../data/intermediary/metadata-with-connected-files-2022-05-23-csv.csv', delimiter=';')
# Out:
# /Users/melvinwevers/opt/miniconda3/envs/hisvis/lib/python3.7/site-packages/IPython/core/interactiveshell.py:3146: DtypeWarning: Columns (3,5,13) have mixed types.Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
categories = meta_df['Catalogus kaart'].str.split('|', expand=True)

# %%
categories[0].nunique()
# Out:
# 1401

# %%
categories = categories[0].dropna().str.lower()

# %%
meta_df = meta_df.dropna(subset=['Catalogus kaart'])

# %%
categories = meta_df['Catalogus kaart'].str.split('|', expand=True)

# %%
meta_df['Invoernummer VH'].value_counts()
# Out:
# 00602A_0001    1
# Name: Invoernummer VH, dtype: int64

# %%
meta_df[meta_df['Catalogus kaart'].str.lower().str.contains('dansen')]

#invoernummer onderwerpskaarten
# Out:
#                                         uuid Invoernummer onderwerpskaarten  \
# 76265   148d0f3d-5d1e-c64b-d73c-7c530391334a                  115325|115324
# 104591  1e324a3d-b6d5-b2b0-3dcd-8baa16da7408                             76
# 104595  ec9d94ba-5cf5-45fc-a74a-7dab7df1efbd                             77
# 104695  4a479ea3-084d-d3ef-ccd7-c85d19efc307                      1610|1611
# 107414  60999a1b-0c4e-0148-86b1-76caae88aaf3                           1334
# ...                                      ...                            ...
# 277374  f29dacac-4663-884c-2667-13a56f03fd62                          64217
# 277445  f2f01c4b-e075-4c32-449b-c9f0013bf834                    23054|23055
# 277793  f50113b3-f6fa-de9a-d8e0-b7f04e037f28                          77124
# 279137  fdcfb042-4e9c-ffb7-4033-7356d0680a53                          31245
# 279293  febc8b67-0208-14f5-11e5-19296ac6b1a1                          61620
#
#                                       Beschrijving  \
# 76265              Dansproject Velserbeek festival
# 104591                     Kinder ballet Maud Kool
# 104595                     Kinder ballet Maud Kool
# 104695  Bloemenkoning bij Volkstam Basken / Doelen
# 107414                               Krelagegebouw
# ...                                            ...
# 277374                 Dansen voor bejaarden, IJm.
# 277445        Spaanse dansen openlucht Bloemendaal
# 277793                       Volksdansen Heemskerk
# 279137    Westfriese Dansgroep bij strand IJmuiden
# 279293                     Jamboree Square Dansers
#
#                                         Catalogus kaart  Clusteronderwerp  \
# 76265   Dansen|Festival, festiviteiten en manifestaties               NaN
# 104591                                           Dansen               NaN
# 104595                                           Dansen               NaN
# 104695                           Bloemenvak|Volksdansen               NaN
# 107414                                      Volksdansen               NaN
# ...                                                 ...               ...
# 277374                                           Dansen               NaN
# 277445                                           Dansen               NaN
# 277793                                      Volksdansen               NaN
# 279137                                           Dansen               NaN
# 279293                                           Dansen               NaN
#
#                            Catalogus kaart scan  \
# 76265   NHA012000004_D_0028|NHA012000006_F_0053
# 104591                      NHA012000004_D_0033
# 104595                      NHA012000004_D_0033
# 104695  NHA012000002_B_0407|NHA012000021_V_0353
# 107414                      NHA012000021_V_0353
# ...                                         ...
# 277374                      NHA012000004_D_0029
# 277445                      NHA012000004_D_0034
# 277793                      NHA012000021_V_0354
# 279137                      NHA012000004_D_0031
# 279293                      NHA012000004_D_0032
#
#                              Plaats, Straat Persoon       Datum  \
# 76265                           Velsen-Zuid     NaN  01-09-1985
# 104591                                  NaN     NaN  01-12-1945
# 104595                                  NaN     NaN  01-12-1945
# 104695                                  NaN     NaN  07-08-1948
# 107414                 Haarlem, Leidsevaart     NaN  30-05-1948
# ...                                     ...     ...         ...
# 277374                                  NaN     NaN  12-11-1975
# 277445  Bloemendaal, Hoge Duin en Daalseweg     NaN  19-06-1962
# 277793                                  NaN     NaN  14-07-1978
# 279137                                  NaN     NaN  07-08-1965
# 279293                                  NaN     NaN  26-04-1975
#
#        Gemaakt in VeleHanden                   Code Logboek pagina ID  \
# 76265                    NaN  NL-HlmNHA_1478_25470K               NaN
# 104591                   NaN  NL-HlmNHA_1478_00294G               NaN
# 104595                   NaN  NL-HlmNHA_1478_00295G               NaN
# 104695                   NaN  NL-HlmNHA_1478_00324A               NaN
# 107414                   NaN  NL-HlmNHA_1478_01215B               NaN
# ...                      ...                    ...               ...
# 277374                   NaN  NL-HlmNHA_1478_14190K               NaN
# 277445                   NaN  NL-HlmNHA_1478_01111K               NaN
# 277793                   NaN  NL-HlmNHA_1478_16924K               NaN
# 279137                   NaN  NL-HlmNHA_1478_03449K               NaN
# 279293                   NaN  NL-HlmNHA_1478_13782K               NaN
#
#        Deelcollectie Invoernummer VH  \
# 76265              K             NaN
# 104591             G             NaN
# 104595             G             NaN
# 104695             A             NaN
# 107414             B             NaN
# ...              ...             ...
# 277374             K             NaN
# 277445             K             NaN
# 277793             K             NaN
# 279137             K             NaN
# 279293             K             NaN
#
#                               Negatiefvel - Logboeknummer  \
# 76265                               NL-HlmNHA_1478_25470K
# 104591  NL-HlmNHA_1478_00294C|NL-HlmNHA_1478_00294G|NL...
# 104595  NL-HlmNHA_1478_00295C|NL-HlmNHA_1478_00295G|NL...
# 104695        NL-HlmNHA_1478_00324A|NL-HlmNHA_1478_00324L
# 107414                              NL-HlmNHA_1478_01215B
# ...                                                   ...
# 277374                              NL-HlmNHA_1478_14190K
# 277445        NL-HlmNHA_1478_01111K|NL-HlmNHA_1478_01111K
# 277793                                                NaN
# 279137                              NL-HlmNHA_1478_03449K
# 279293                              NL-HlmNHA_1478_13782K
#
#        Negatiefvel - Kaartnummer         Negatiefvel - Serie naam  \
# 76265                         00                  Kleinbeeld 1985
# 104591            00|00_01|00_01                 C Kleur|G 2015|L
# 104595            00|00_01|00_01                 C Kleur|G 2015|L
# 104695                  00|00_01                       6x6 1948|L
# 107414                     00_01                      B 1935-1958
# ...                          ...                              ...
# 277374                        00                  Kleinbeeld 1975
# 277445                     01|02  Kleinbeeld 1962|Kleinbeeld 1962
# 277793                       NaN                              NaN
# 279137                        00                  Kleinbeeld 1965
# 279293                        00                  Kleinbeeld 1975
#
#         Aantal foto's
# 76265               6
# 104591              1
# 104595              1
# 104695              0
# 107414              1
# ...               ...
# 277374              6
# 277445             71
# 277793              0
# 279137             10
# 279293              6
#
# [362 rows x 18 columns]

# %% [markdown]
# ## Finding new data

# %%
dfused1 = pd.read_csv('../data/intermediary/VHproject2deel1.csv')
dfused2 = pd.read_csv('../data/intermediary/VHproject2deel2.csv')

df_used = pd.concat([dfused1, dfused2])

meta_df = pd.read_csv('../data/intermediary/metadata-with-connected-files-2022-05-23-csv.csv', delimiter=';')
# Out:
# /Users/melvinwevers/opt/miniconda3/envs/hisvis/lib/python3.7/site-packages/IPython/core/interactiveshell.py:3146: DtypeWarning: Columns (3,5,13) have mixed types.Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
extra_training = list(set(extra_training + decreased_acc))

sorted(extra_training)
print(len(extra_training))

np.savetxt("extra_training_labels.csv", 
           sorted(extra_training),
           delimiter =", ", 
           fmt ='% s')
# Out:
# 51

# %%
## remove historisch toneelstuk, mensen_op_trap

for label in extra_training:
    if label == 'amfitheater':
       extra_training.append('openluchttheater')
    elif label == 'dansende_mensen':
       extra_training.append('dansen')
    elif label == 'mensen_op_een_boot':
       extra_training.append('visserij')
       extra_training.append('boot')
    elif label == 'kerk_binnen':
        extra_training.remove('kerk_binnen')
        extra_training.append('kerk')
    elif label == 'ongeluk_brancard':
        
        extra_training.append('brancard')
    elif label == 'schaken_damen':
        
        extra_training.append('schaken')
        extra_training.append('dammen')
    elif label == 'tafel_tennis':
        
        extra_training.append('tafeltennis')
    elif label == 'trein_ongeluk':
        
        extra_training.append('treinongeluk')
        extra_training.append('treinstation')
    elif label == 'vlag_hijsen':
        
        extra_training.append('vlag hijsen')
  

extra_training.remove('mensen_op_een_boot')
extra_training.remove('sport_overig')
extra_training.remove('mensen_op_trap')
extra_training.remove('amfitheater')
extra_training.remove('vlag_hijsen')    
extra_training.remove('trein_ongeluk')    
extra_training.remove('schaken_dammen')    
extra_training.remove('ongeluk_brancard')     
extra_training.remove('dansende_mensen')   
extra_training.remove('tafel_tennis')

# %%
meta_df['Beschrijving'] = meta_df['Beschrijving'].str.lower()
meta_df['Catalogus kaart'] = meta_df['Catalogus kaart'].str.lower().str.replace("|", " ")

# %%
df_numbers = df_used['t3_entry_number'].str[1:-1].str.split(',', expand=True)
df_numbers = pd.merge(df_numbers, df_used['t3_vh_entry_number'], left_index=True, right_index=True)

used_numbers = []
for col in df_numbers:
    unique_vals = list(df_numbers[col].unique())
    for val in unique_vals:
        if val in used_numbers:
            pass
        else: 
            used_numbers.append(val)

# %%
def get_card_numbers(df):
    card_numbers = []
    for index, row, in df.iterrows():
        x = row['Invoernummer onderwerpskaarten']
        if x is np.nan:
            x = row['Invoernummer VH']
            card_numbers.append(x)
        elif '|' in x:
            x = x.split('|')
            for _ in x:
                card_numbers.append(_)
        else:
            card_numbers.append(x)
    return card_numbers

def find_numbers(meta_df, used_numbers, label):
    query = r'\b({})\b'.format(label)
    selection = meta_df.loc[meta_df['Catalogus kaart'].str.contains(query, na=False, regex=True) | 
meta_df['Beschrijving'].str.contains(query, na=False, regex=True)]
    #print(selection['Beschrijving'].head())

    print(f'found {selection.shape[0]} records')
    

    numbers = get_card_numbers(selection)
    print(f'found {len(numbers)} card numbers')

    # filter out used numbers
    numbers = [number for number in numbers if number not in used_numbers]
    print(f'found {len(numbers)} unused card numbers')
    print('\n')
    print('--------')

    return numbers

# %%
numbers_needed = {}

for label in extra_training:
    print(label)
    numbers_needed[label] = find_numbers(meta_df, used_numbers, label)

# %%
cards_ = 0
for k, v in numbers_needed.items():
    cards_ += len(v)

# %%
df = pd.DataFrame(list(numbers_needed.items()),columns = ['label','list_of_numbers'])

# %%
df.to_csv('numbers_needed.csv')

with open("numbers_needed.json", "w") as outfile:
    json.dump(numbers_needed, outfile)
