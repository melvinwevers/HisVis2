# %%
# !pip install sentence-transformers
# !pip install fastai
# !pip install git+https://github.com/openai/CLIP.git
# !pip install newlinejson
# Out:
# Collecting sentence-transformers
#   Downloading sentence-transformers-2.1.0.tar.gz (78 kB)
#      |████████████████████████████████| 78 kB 524 kB/s eta 0:00:01
# Collecting transformers<5.0.0,>=4.6.0
#   Downloading transformers-4.12.5-py3-none-any.whl (3.1 MB)
#      |████████████████████████████████| 3.1 MB 10.5 MB/s eta 0:00:01
# Collecting tokenizers>=0.10.3
#   Downloading tokenizers-0.10.3-cp39-cp39-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_12_x86_64.manylinux2010_x86_64.whl (3.3 MB)
#      |████████████████████████████████| 3.3 MB 28.4 MB/s eta 0:00:01
# Requirement already satisfied: tqdm in /opt/conda/lib/python3.9/site-packages (from sentence-transformers) (4.61.2)
# Collecting torch>=1.6.0
#   Downloading torch-1.10.0-cp39-cp39-manylinux1_x86_64.whl (881.9 MB)
#      |███████████▍                    | 312.8 MB 145.4 MB/s eta 0:00:04
# IOPub data rate exceeded.
# The Jupyter server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--ServerApp.iopub_data_rate_limit`.
#
# Current values:
# ServerApp.iopub_data_rate_limit=1000000.0 (bytes/sec)
# ServerApp.rate_limit_window=3.0 (secs)
#      |███████████████████████████▉    | 766.4 MB 151.5 MB/s eta 0:00:01
# IOPub data rate exceeded.
# The Jupyter server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--ServerApp.iopub_data_rate_limit`.
#
# Current values:
# ServerApp.iopub_data_rate_limit=1000000.0 (bytes/sec)
# ServerApp.rate_limit_window=3.0 (secs)
#      |████████████████████████████████| 881.9 MB 2.6 kB/s
# Collecting torchvision
#   Downloading torchvision-0.11.1-cp39-cp39-manylinux1_x86_64.whl (23.2 MB)
#      |████████████████████████████████| 23.2 MB 36.0 MB/s eta 0:00:01
# Requirement already satisfied: numpy in /opt/conda/lib/python3.9/site-packages (from sentence-transformers) (1.21.1)
# Collecting scikit-learn
#   Downloading scikit_learn-1.0.1-cp39-cp39-manylinux_2_12_x86_64.manylinux2010_x86_64.whl (24.7 MB)
#      |████████████████████████████████| 24.7 MB 29.7 MB/s eta 0:00:01
# Requirement already satisfied: scipy in /opt/conda/lib/python3.9/site-packages (from sentence-transformers) (1.7.0)
# Collecting nltk
#   Downloading nltk-3.6.5-py3-none-any.whl (1.5 MB)
#      |████████████████████████████████| 1.5 MB 23.7 MB/s eta 0:00:01
# Collecting sentencepiece
#   Downloading sentencepiece-0.1.96-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.2 MB)
#      |████████████████████████████████| 1.2 MB 24.7 MB/s eta 0:00:01
# Collecting huggingface-hub
#   Downloading huggingface_hub-0.2.1-py3-none-any.whl (61 kB)
#      |████████████████████████████████| 61 kB 61 kB/s s eta 0:00:01
# Requirement already satisfied: typing-extensions in /opt/conda/lib/python3.9/site-packages (from torch>=1.6.0->sentence-transformers) (3.10.0.0)
# Collecting filelock
#   Downloading filelock-3.4.0-py3-none-any.whl (9.8 kB)
# Requirement already satisfied: regex!=2019.12.17 in /opt/conda/lib/python3.9/site-packages (from transformers<5.0.0,>=4.6.0->sentence-transformers) (2021.7.6)
# Requirement already satisfied: requests in /opt/conda/lib/python3.9/site-packages (from transformers<5.0.0,>=4.6.0->sentence-transformers) (2.26.0)
# Requirement already satisfied: packaging>=20.0 in /opt/conda/lib/python3.9/site-packages (from transformers<5.0.0,>=4.6.0->sentence-transformers) (21.0)
# Collecting sacremoses
#   Downloading sacremoses-0.0.46-py3-none-any.whl (895 kB)
#      |████████████████████████████████| 895 kB 29.3 MB/s eta 0:00:01
# Requirement already satisfied: pyyaml>=5.1 in /opt/conda/lib/python3.9/site-packages (from transformers<5.0.0,>=4.6.0->sentence-transformers) (5.4.1)
# Requirement already satisfied: pyparsing>=2.0.2 in /opt/conda/lib/python3.9/site-packages (from packaging>=20.0->transformers<5.0.0,>=4.6.0->sentence-transformers) (2.4.7)
# Collecting joblib
#   Downloading joblib-1.1.0-py2.py3-none-any.whl (306 kB)
#      |████████████████████████████████| 306 kB 32.0 MB/s eta 0:00:01
# Collecting regex!=2019.12.17
#   Downloading regex-2021.11.10-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (763 kB)
#      |████████████████████████████████| 763 kB 30.4 MB/s eta 0:00:01
# Requirement already satisfied: click in /opt/conda/lib/python3.9/site-packages (from nltk->sentence-transformers) (8.0.1)
# Requirement already satisfied: idna<4,>=2.5 in /opt/conda/lib/python3.9/site-packages (from requests->transformers<5.0.0,>=4.6.0->sentence-transformers) (3.1)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/conda/lib/python3.9/site-packages (from requests->transformers<5.0.0,>=4.6.0->sentence-transformers) (2021.5.30)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /opt/conda/lib/python3.9/site-packages (from requests->transformers<5.0.0,>=4.6.0->sentence-transformers) (1.26.6)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /opt/conda/lib/python3.9/site-packages (from requests->transformers<5.0.0,>=4.6.0->sentence-transformers) (2.0.0)
# Requirement already satisfied: six in /opt/conda/lib/python3.9/site-packages (from sacremoses->transformers<5.0.0,>=4.6.0->sentence-transformers) (1.16.0)
# Collecting threadpoolctl>=2.0.0
#   Downloading threadpoolctl-3.0.0-py3-none-any.whl (14 kB)
# Requirement already satisfied: pillow!=8.3.0,>=5.3.0 in /opt/conda/lib/python3.9/site-packages (from torchvision->sentence-transformers) (8.3.1)
# Building wheels for collected packages: sentence-transformers
#   Building wheel for sentence-transformers (setup.py) ... done
#   Created wheel for sentence-transformers: filename=sentence_transformers-2.1.0-py3-none-any.whl size=120999 sha256=ab30279dd550c8c45720b4c76d41004b5310a469286f9b9200117b2f13d72bb0
#   Stored in directory: /home/ucloud/.cache/pip/wheels/17/1d/fd/a16123b417c527e0452c3e10ae5139cd2ab2f6fee93e892441
# Successfully built sentence-transformers
# Installing collected packages: regex, joblib, filelock, torch, tokenizers, threadpoolctl, sacremoses, huggingface-hub, transformers, torchvision, sentencepiece, scikit-learn, nltk, sentence-transformers
#   Attempting uninstall: regex
#     Found existing installation: regex 2021.7.6
#     Uninstalling regex-2021.7.6:
#       Successfully uninstalled regex-2021.7.6
# Successfully installed filelock-3.4.0 huggingface-hub-0.2.1 joblib-1.1.0 nltk-3.6.5 regex-2021.11.10 sacremoses-0.0.46 scikit-learn-1.0.1 sentence-transformers-2.1.0 sentencepiece-0.1.96 threadpoolctl-3.0.0 tokenizers-0.10.3 torch-1.10.0 torchvision-0.11.1 transformers-4.12.5
# Collecting fastai
#   Downloading fastai-2.5.3-py3-none-any.whl (189 kB)
#      |████████████████████████████████| 189 kB 4.1 MB/s eta 0:00:01
# Collecting fastcore<1.4,>=1.3.22
#   Downloading fastcore-1.3.27-py3-none-any.whl (56 kB)
#      |████████████████████████████████| 56 kB 700 kB/s  eta 0:00:01
# Collecting fastdownload<2,>=0.0.5
#   Downloading fastdownload-0.0.5-py3-none-any.whl (13 kB)
# Requirement already satisfied: pip in /opt/conda/lib/python3.9/site-packages (from fastai) (21.2.1)
# Collecting fastprogress>=0.2.4
#   Downloading fastprogress-1.0.0-py3-none-any.whl (12 kB)
# Requirement already satisfied: matplotlib in /opt/conda/lib/python3.9/site-packages (from fastai) (3.4.2)
# Requirement already satisfied: scikit-learn in /opt/conda/lib/python3.9/site-packages (from fastai) (1.0.1)
# Requirement already satisfied: requests in /opt/conda/lib/python3.9/site-packages (from fastai) (2.26.0)
# Requirement already satisfied: pyyaml in /opt/conda/lib/python3.9/site-packages (from fastai) (5.4.1)
# Requirement already satisfied: torchvision>=0.8.2 in /opt/conda/lib/python3.9/site-packages (from fastai) (0.11.1)
# Requirement already satisfied: packaging in /opt/conda/lib/python3.9/site-packages (from fastai) (21.0)
# Requirement already satisfied: pandas in /opt/conda/lib/python3.9/site-packages (from fastai) (1.3.1)
# Requirement already satisfied: pillow>6.0.0 in /opt/conda/lib/python3.9/site-packages (from fastai) (8.3.1)
# Requirement already satisfied: scipy in /opt/conda/lib/python3.9/site-packages (from fastai) (1.7.0)
# Requirement already satisfied: torch<1.11,>=1.7.0 in /opt/conda/lib/python3.9/site-packages (from fastai) (1.10.0)
# Collecting spacy<4
#   Downloading spacy-3.2.1-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (6.1 MB)
#      |████████████████████████████████| 6.1 MB 21.8 MB/s eta 0:00:01
# Requirement already satisfied: numpy in /opt/conda/lib/python3.9/site-packages (from fastprogress>=0.2.4->fastai) (1.21.1)
# Collecting blis<0.8.0,>=0.4.0
#   Downloading blis-0.7.5-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (9.9 MB)
#      |████████████████████████████████| 9.9 MB 21.6 MB/s eta 0:00:01
# Collecting pydantic!=1.8,!=1.8.1,<1.9.0,>=1.7.4
#   Downloading pydantic-1.8.2-cp39-cp39-manylinux2014_x86_64.whl (11.3 MB)
#      |████████████████████████████████| 11.3 MB 26.6 MB/s eta 0:00:01
# Collecting catalogue<2.1.0,>=2.0.6
#   Downloading catalogue-2.0.6-py3-none-any.whl (17 kB)
# Collecting langcodes<4.0.0,>=3.2.0
#   Downloading langcodes-3.3.0-py3-none-any.whl (181 kB)
#      |████████████████████████████████| 181 kB 33.1 MB/s eta 0:00:01
# Collecting preshed<3.1.0,>=3.0.2
#   Downloading preshed-3.0.6-cp39-cp39-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (128 kB)
#      |████████████████████████████████| 128 kB 32.9 MB/s eta 0:00:01
# Collecting typer<0.5.0,>=0.3.0
#   Downloading typer-0.4.0-py3-none-any.whl (27 kB)
# Collecting cymem<2.1.0,>=2.0.2
#   Downloading cymem-2.0.6-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (35 kB)
# Collecting murmurhash<1.1.0,>=0.28.0
#   Downloading murmurhash-1.0.6-cp39-cp39-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (21 kB)
# Requirement already satisfied: setuptools in /opt/conda/lib/python3.9/site-packages (from spacy<4->fastai) (49.6.0.post20210108)
# Collecting srsly<3.0.0,>=2.4.1
#   Downloading srsly-2.4.2-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (452 kB)
#      |████████████████████████████████| 452 kB 33.0 MB/s eta 0:00:01
# Collecting wasabi<1.1.0,>=0.8.1
#   Downloading wasabi-0.9.0-py3-none-any.whl (25 kB)
# Collecting pathy>=0.3.5
#   Downloading pathy-0.6.1-py3-none-any.whl (42 kB)
#      |████████████████████████████████| 42 kB 164 kB/s  eta 0:00:01
# Collecting spacy-loggers<2.0.0,>=1.0.0
#   Downloading spacy_loggers-1.0.1-py3-none-any.whl (7.0 kB)
# Collecting thinc<8.1.0,>=8.0.12
#   Downloading thinc-8.0.13-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (635 kB)
#      |████████████████████████████████| 635 kB 34.0 MB/s eta 0:00:01
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in /opt/conda/lib/python3.9/site-packages (from spacy<4->fastai) (4.61.2)
# Requirement already satisfied: jinja2 in /opt/conda/lib/python3.9/site-packages (from spacy<4->fastai) (3.0.1)
# Collecting spacy-legacy<3.1.0,>=3.0.8
#   Downloading spacy_legacy-3.0.8-py2.py3-none-any.whl (14 kB)
# Requirement already satisfied: pyparsing>=2.0.2 in /opt/conda/lib/python3.9/site-packages (from packaging->fastai) (2.4.7)
# Collecting smart-open<6.0.0,>=5.0.0
#   Downloading smart_open-5.2.1-py3-none-any.whl (58 kB)
#      |████████████████████████████████| 58 kB 333 kB/s  eta 0:00:01
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /opt/conda/lib/python3.9/site-packages (from pydantic!=1.8,!=1.8.1,<1.9.0,>=1.7.4->spacy<4->fastai) (3.10.0.0)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /opt/conda/lib/python3.9/site-packages (from requests->fastai) (1.26.6)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/conda/lib/python3.9/site-packages (from requests->fastai) (2021.5.30)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /opt/conda/lib/python3.9/site-packages (from requests->fastai) (2.0.0)
# Requirement already satisfied: idna<4,>=2.5 in /opt/conda/lib/python3.9/site-packages (from requests->fastai) (3.1)
# Requirement already satisfied: click<9.0.0,>=7.1.1 in /opt/conda/lib/python3.9/site-packages (from typer<0.5.0,>=0.3.0->spacy<4->fastai) (8.0.1)
# Requirement already satisfied: MarkupSafe>=2.0 in /opt/conda/lib/python3.9/site-packages (from jinja2->spacy<4->fastai) (2.0.1)
# Requirement already satisfied: kiwisolver>=1.0.1 in /opt/conda/lib/python3.9/site-packages (from matplotlib->fastai) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in /opt/conda/lib/python3.9/site-packages (from matplotlib->fastai) (0.10.0)
# Requirement already satisfied: python-dateutil>=2.7 in /opt/conda/lib/python3.9/site-packages (from matplotlib->fastai) (2.8.2)
# Requirement already satisfied: six in /opt/conda/lib/python3.9/site-packages (from cycler>=0.10->matplotlib->fastai) (1.16.0)
# Requirement already satisfied: pytz>=2017.3 in /opt/conda/lib/python3.9/site-packages (from pandas->fastai) (2021.1)
# Requirement already satisfied: joblib>=0.11 in /opt/conda/lib/python3.9/site-packages (from scikit-learn->fastai) (1.1.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /opt/conda/lib/python3.9/site-packages (from scikit-learn->fastai) (3.0.0)
# Installing collected packages: murmurhash, cymem, catalogue, wasabi, typer, srsly, smart-open, pydantic, preshed, blis, thinc, spacy-loggers, spacy-legacy, pathy, langcodes, fastprogress, fastcore, spacy, fastdownload, fastai
# Successfully installed blis-0.7.5 catalogue-2.0.6 cymem-2.0.6 fastai-2.5.3 fastcore-1.3.27 fastdownload-0.0.5 fastprogress-1.0.0 langcodes-3.3.0 murmurhash-1.0.6 pathy-0.6.1 preshed-3.0.6 pydantic-1.8.2 smart-open-5.2.1 spacy-3.2.1 spacy-legacy-3.0.8 spacy-loggers-1.0.1 srsly-2.4.2 thinc-8.0.13 typer-0.4.0 wasabi-0.9.0
# Collecting git+https://github.com/openai/CLIP.git
#   Cloning https://github.com/openai/CLIP.git to /tmp/pip-req-build-p7182jcp
#   Running command git clone -q https://github.com/openai/CLIP.git /tmp/pip-req-build-p7182jcp
#   Resolved https://github.com/openai/CLIP.git to commit 573315e83f07b53a61ff5098757e8fc885f1703e
# Collecting ftfy
#   Downloading ftfy-6.0.3.tar.gz (64 kB)
#      |████████████████████████████████| 64 kB 462 kB/s eta 0:00:011
# Requirement already satisfied: regex in /opt/conda/lib/python3.9/site-packages (from clip==1.0) (2021.11.10)
# Requirement already satisfied: tqdm in /opt/conda/lib/python3.9/site-packages (from clip==1.0) (4.61.2)
# Requirement already satisfied: torch in /opt/conda/lib/python3.9/site-packages (from clip==1.0) (1.10.0)
# Requirement already satisfied: torchvision in /opt/conda/lib/python3.9/site-packages (from clip==1.0) (0.11.1)
# Requirement already satisfied: wcwidth in /opt/conda/lib/python3.9/site-packages (from ftfy->clip==1.0) (0.2.5)
# Requirement already satisfied: typing-extensions in /opt/conda/lib/python3.9/site-packages (from torch->clip==1.0) (3.10.0.0)
# Requirement already satisfied: pillow!=8.3.0,>=5.3.0 in /opt/conda/lib/python3.9/site-packages (from torchvision->clip==1.0) (8.3.1)
# Requirement already satisfied: numpy in /opt/conda/lib/python3.9/site-packages (from torchvision->clip==1.0) (1.21.1)
# Building wheels for collected packages: clip, ftfy
#   Building wheel for clip (setup.py) ... done
#   Created wheel for clip: filename=clip-1.0-py3-none-any.whl size=1369094 sha256=f52991d51650b80cbda0deb621a142202039c8a7623807befe27370f68102d4c
#   Stored in directory: /tmp/pip-ephem-wheel-cache-i5ua2gpi/wheels/c8/e4/e1/11374c111387672fc2068dfbe0d4b424cb9cdd1b2e184a71b5
#   Building wheel for ftfy (setup.py) ... done
#   Created wheel for ftfy: filename=ftfy-6.0.3-py3-none-any.whl size=41913 sha256=fca2d64f8ea95415d52ab32bb638afbcf34f59f5f8f9b9837b90c3c7ba413ed9
#   Stored in directory: /home/ucloud/.cache/pip/wheels/3d/ee/4b/03a4e2e591ea56687aff999edc83827a2ace523baab75b8e41
# Successfully built clip ftfy
# Installing collected packages: ftfy, clip
# Successfully installed clip-1.0 ftfy-6.0.3
# Collecting newlinejson
#   Downloading NewlineJSON-1.0-py2.py3-none-any.whl (12 kB)
# Requirement already satisfied: six in /opt/conda/lib/python3.9/site-packages (from newlinejson) (1.16.0)
# Installing collected packages: newlinejson
# Successfully installed newlinejson-1.0
